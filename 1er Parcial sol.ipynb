# %% [markdown]
# ## 1er Parcial - Simulación Computacional 2019-I

# %% [markdown]
# **1)** Para los siguientes generadores congruenciales mixtos encuentre $u_1,...,u_{100}$, el tamaño del ciclo (si lo tiene) y calcule el estadístico $\chi^2$
#
# **(a)** $x_0=3, x_n = (5x_{n-1}+7) \mod 200$

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import math

import scipy.stats as stats

def pruebaChi(secuencia=[]):
    canpart=10
    print("con un valor de K=",canpart)
    longitudIntervalo = 1 / float(canpart) 
    frecuenciasObservadas = []           


    for i in range(0,canpart):
        frecuenciasObservadas.append(0)
        
    

   
    
    for i in range(len(secuencia)):
        cont = 1
        for j in range(0,canpart):     
            if secuencia[i] > (cont - 1) * longitudIntervalo and secuencia[i] <= cont * longitudIntervalo:
                frecuenciasObservadas[j] += 1
            cont += 1 
            
    #print("las frecuencias observadas:\n",frecuenciasObservadas)
        
    frecuenciaEsperada = len(secuencia) / float(canpart)
    chiCuadrado = 0.0
        
    for i in range(0,canpart):
        chiCuadrado += (frecuenciasObservadas[i] - frecuenciaEsperada)**2 / frecuenciaEsperada
    #print("valor final: ")
    
    print ("Prueba del simulador=",chiCuadrado)
    
    crit = stats.chi2.ppf(q = 0.95,df = canpart)
    crit=round(crit,4)
    print("Con 95%=",crit)

    if(chiCuadrado<crit):
        print("Aceptada la hipotesis de uniformidad chi-cuadrado")
    
    else:
        print("Rechazada la hipotesis de uniformidad chi-cuadrado")

def periodo(lista):
    a=lista[6];
    try:
        
        ci=(lista.index(a, 7))-6;
        print("El periodo observado de este generador es= ",ci);
    except ValueError:
        print("no se halla un periodo en este generador");

def mixto1():
    x=3
    lista=[]
    i=0
    while i < 100:
        x=((x*5)+7)%200
        u=x/200
        lista.append(u)
        print("U",i+1,"=",u)
        i+=1
    return lista

lista1=mixto1()
periodo(lista1)
print("prueba de chi-cuadrado:")
pruebaChi(lista1)
# Out:
# U 1 = 0.11
# U 2 = 0.585
# U 3 = 0.96
# U 4 = 0.835
# U 5 = 0.21
# U 6 = 0.085
# U 7 = 0.46
# U 8 = 0.335
# U 9 = 0.71
# U 10 = 0.585
# U 11 = 0.96
# U 12 = 0.835
# U 13 = 0.21
# U 14 = 0.085
# U 15 = 0.46
# U 16 = 0.335
# U 17 = 0.71
# U 18 = 0.585
# U 19 = 0.96
# U 20 = 0.835
# U 21 = 0.21
# U 22 = 0.085
# U 23 = 0.46
# U 24 = 0.335
# U 25 = 0.71
# U 26 = 0.585
# U 27 = 0.96
# U 28 = 0.835
# U 29 = 0.21
# U 30 = 0.085
# U 31 = 0.46
# U 32 = 0.335
# U 33 = 0.71
# U 34 = 0.585
# U 35 = 0.96
# U 36 = 0.835
# U 37 = 0.21
# U 38 = 0.085
# U 39 = 0.46
# U 40 = 0.335
# U 41 = 0.71
# U 42 = 0.585
# U 43 = 0.96
# U 44 = 0.835
# U 45 = 0.21
# U 46 = 0.085
# U 47 = 0.46
# U 48 = 0.335
# U 49 = 0.71
# U 50 = 0.585
# U 51 = 0.96
# U 52 = 0.835
# U 53 = 0.21
# U 54 = 0.085
# U 55 = 0.46
# U 56 = 0.335
# U 57 = 0.71
# U 58 = 0.585
# U 59 = 0.96
# U 60 = 0.835
# U 61 = 0.21
# U 62 = 0.085
# U 63 = 0.46
# U 64 = 0.335
# U 65 = 0.71
# U 66 = 0.585
# U 67 = 0.96
# U 68 = 0.835
# U 69 = 0.21
# ...

# %% [markdown]
# **(b)** $x_0=123, x_n = (13x_{n-1}+3) \mod 16$

# %%
def mixto2():
    x=123
    lista=[]
    i=0
    while i < 100:
        x=((x*13)+3)%16
        u=x/16
        lista.append(u)
        print("U",i+1,"=",u)
        i+=1
        
    return lista

lista2=mixto2()
periodo(lista2)
print("prueba de chi-cuadrado:")
pruebaChi(lista2)
# Out:
# U 1 = 0.125
# U 2 = 0.8125
# U 3 = 0.75
# U 4 = 0.9375
# U 5 = 0.375
# U 6 = 0.0625
# U 7 = 0.0
# U 8 = 0.1875
# U 9 = 0.625
# U 10 = 0.3125
# U 11 = 0.25
# U 12 = 0.4375
# U 13 = 0.875
# U 14 = 0.5625
# U 15 = 0.5
# U 16 = 0.6875
# U 17 = 0.125
# U 18 = 0.8125
# U 19 = 0.75
# U 20 = 0.9375
# U 21 = 0.375
# U 22 = 0.0625
# U 23 = 0.0
# U 24 = 0.1875
# U 25 = 0.625
# U 26 = 0.3125
# U 27 = 0.25
# U 28 = 0.4375
# U 29 = 0.875
# U 30 = 0.5625
# U 31 = 0.5
# U 32 = 0.6875
# U 33 = 0.125
# U 34 = 0.8125
# U 35 = 0.75
# U 36 = 0.9375
# U 37 = 0.375
# U 38 = 0.0625
# U 39 = 0.0
# U 40 = 0.1875
# U 41 = 0.625
# U 42 = 0.3125
# U 43 = 0.25
# U 44 = 0.4375
# U 45 = 0.875
# U 46 = 0.5625
# U 47 = 0.5
# U 48 = 0.6875
# U 49 = 0.125
# U 50 = 0.8125
# U 51 = 0.75
# U 52 = 0.9375
# U 53 = 0.375
# U 54 = 0.0625
# U 55 = 0.0
# U 56 = 0.1875
# U 57 = 0.625
# U 58 = 0.3125
# U 59 = 0.25
# U 60 = 0.4375
# U 61 = 0.875
# U 62 = 0.5625
# U 63 = 0.5
# U 64 = 0.6875
# U 65 = 0.125
# U 66 = 0.8125
# ...

# %% [markdown]
# **(c)** $x_0=7, x_n = (5x_{n-1}+3) \mod 33$

# %%
def mixto3():
    x=7
    lista=[]
    i=0
    while i < 100:
        x=((x*5)+3)%33
        u=x/200
        lista.append(u)
        print("U",i+1,"=",u)
        
        i+=1
    return lista
lista3=mixto3()
periodo(lista3)
print("prueba de chi-cuadrado:")
pruebaChi(lista3)
# Out:
# U 1 = 0.025
# U 2 = 0.14
# U 3 = 0.055
# U 4 = 0.125
# U 5 = 0.145
# U 6 = 0.08
# U 7 = 0.085
# U 8 = 0.11
# U 9 = 0.07
# U 10 = 0.035
# U 11 = 0.025
# U 12 = 0.14
# U 13 = 0.055
# U 14 = 0.125
# U 15 = 0.145
# U 16 = 0.08
# U 17 = 0.085
# U 18 = 0.11
# U 19 = 0.07
# U 20 = 0.035
# U 21 = 0.025
# U 22 = 0.14
# U 23 = 0.055
# U 24 = 0.125
# U 25 = 0.145
# U 26 = 0.08
# U 27 = 0.085
# U 28 = 0.11
# U 29 = 0.07
# U 30 = 0.035
# U 31 = 0.025
# U 32 = 0.14
# U 33 = 0.055
# U 34 = 0.125
# U 35 = 0.145
# U 36 = 0.08
# U 37 = 0.085
# U 38 = 0.11
# U 39 = 0.07
# U 40 = 0.035
# U 41 = 0.025
# U 42 = 0.14
# U 43 = 0.055
# U 44 = 0.125
# U 45 = 0.145
# U 46 = 0.08
# U 47 = 0.085
# U 48 = 0.11
# U 49 = 0.07
# U 50 = 0.035
# U 51 = 0.025
# U 52 = 0.14
# U 53 = 0.055
# U 54 = 0.125
# U 55 = 0.145
# U 56 = 0.08
# U 57 = 0.085
# U 58 = 0.11
# U 59 = 0.07
# U 60 = 0.035
# U 61 = 0.025
# U 62 = 0.14
# U 63 = 0.055
# U 64 = 0.125
# U 65 = 0.145
# U 66 = 0.08
# U 67 = 0.085
# U 68 = 0.11
# U 69 = 0.07
# ...

# %% [markdown]
# **2)** Para las siguientes integrales, use simulación con el generado congruencial mixto $x_0=6789, x_n = (25214903917 x_{n-1}+11) \mod 2^{48}-1$ para aproximar el valor de las integrales para $N=100, 1000, 10000$, y compare su estimación con el valor real calculando el error relativo porcentual:
#
# **(a)** $\int_{0}^{1}e ^{sin(x)}dx$

# %%
import random
def error(a,b):
    rr=(np.absolute(a-b)/b)*100
    return rr
def mixton():
    x=5789
    lista=[]
    i=0
    while i < 10000:
        x=((x*25214903917)+11)%((2**48)-1)
        u=x/((2**48)-1)
        lista.append(u)
        #print("U",i+1,"=",u)
        
        i+=1
    return lista


def mt1(n,lista=[]):
    #fu=input("Introduce la funcion a evaluar: ");
    
    suma=0;
    i=0;
    while i < n:
    
        u=lista[i];
        #x=u;
        #y=eval(fu)
        y=math.exp(math.sin(u))
        #y=sp.sympify(fu).subs(x,u);
        #y=math.exp(-u*u);
        suma+=y;
        i += 1;
    #print(suma); 
    return(suma/n); 

listadef=mixton()
resul=1.63186960841805
result1=mt1(100,listadef)
result2=mt1(1000,listadef)
result3=mt1(10000,listadef)
print("Resultado real de la integral=",resul,"\n")
print("Para n=100 da como resultado=", result1)

print("Con un error porcentual de=",error(result1,resul),"%\n")
print("Para n=1000 da como resultado=",result2)
print("Con un error porcentual de=",error(result2,resul),"%\n")
print("Para n=10000 da como resultado=",result3)
print("Con un error porcentual de=",error(result3,resul),"%\n")
# Out:
# Resultado real de la integral= 1.63186960841805
#
# Para n=100 da como resultado= 1.7331704501493512
# Con un error porcentual de= 6.207655391627967 %
#
# Para n=1000 da como resultado= 1.6450911606133107
# Con un error porcentual de= 0.8102088627091889 %
#
# Para n=10000 da como resultado= 1.6328179418572206
# Con un error porcentual de= 0.058113309683485756 %

# %% [markdown]
# **(b)** $\int_{-3}^{3}e^{sin(x)-x^{3}}dx$

# %%
def mt2(n,lista=[]):
    #fu=input("Introduce la funcion a evaluar: ");
    suma=0;
    i=0;
    dist=6;
    while i < n:
    
        
        ra=(-3+(dist*lista[i]));
        
        #x=u;
        #y=eval(fu)
        y=math.exp((math.sin(ra))-ra**3)
        #y=sp.sympify(fu).subs(x,u);
        #y=math.exp(-u*u);
        suma+=y;
        i += 1;
    #print(suma);
    return(dist*suma/n);

resul=1.69143*(10**10)
result4=mt2(100,listadef)
result5=mt2(1000,listadef)
result6=mt2(10000,listadef)
print("Resultado real de la integral=",resul,"\n")
print("Para n=100 da como resultado=", result4)

print("Con un error porcentual de=",error(result4,resul),"%\n")
print("Para n=1000 da como resultado=",result5)
print("Con un error porcentual de=",error(result5,resul),"%\n")
print("Para n=10000 da como resultado=",result6)
print("Con un error porcentual de=",error(result6,resul),"%\n")
# Out:
# Resultado real de la integral= 16914300000.0
#
# Para n=100 da como resultado= 4467855932.269626
# Con un error porcentual de= 73.58533352092829 %
#
# Para n=1000 da como resultado= 13556742587.150152
# Con un error porcentual de= 19.85040712799139 %
#
# Para n=10000 da como resultado= 14126976020.069319
# Con un error porcentual de= 16.47909744967679 %

# %% [markdown]
# **(c)** $\int_{0}^{1}(\sin(1+x^{2}))^{3/2}dx$

# %%
def mt3(n,lista=[]):
    #fu=input("Introduce la funcion a evaluar: ");
    
    suma=0;
    i=0;
    while i < n:
    
        u=lista[i];
        #x=u;
        #y=eval(fu)
        y=(math.sin(1+u**2))**(1.5)
        #y=sp.sympify(fu).subs(x,u);
        #y=math.exp(-u*u);
        suma+=y;
        i += 1;
    #print(suma); 
    return(suma/n); 


result=0.896282
result1=mt1(100,listadef)
result2=mt1(1000,listadef)
result3=mt1(10000,listadef)
print("Resultado real de la integral=",result,"\n")
print("Para n=100 da como resultado=", result1)

print("Con un error porcentual de=",error(result1,result),"%\n")
print("Para n=1000 da como resultado=",result2)
print("Con un error porcentual de=",error(result2,result),"%\n")
print("Para n=10000 da como resultado=",result3)
print("Con un error porcentual de=",error(result3,result),"%\n")
# Out:
# Resultado real de la integral= 0.896282
#
# Para n=100 da como resultado= 0.914757632331237
# Con un error porcentual de= 2.061363759535163 %
#
# Para n=1000 da como resultado= 0.8990027314240636
# Con un error porcentual de= 0.3035575214121888 %
#
# Para n=10000 da como resultado= 0.8974767332347288
# Con un error porcentual de= 0.13329880938462893 %

# %% [markdown]
# **3)** Dados los siguientes valores de la distribución de probabilidad discreta de la variable aleatoria $X$ de un dado de 8 lados: $X = {1,2,3,4,5,6,7,8}$, $p(X) = {0.11,0.3,0.12,0.2,0.05,0.07,0.05,0.10}$, ¿Qué valores retornaría el generador de variables aleatorias por el método de la inversión si los números aleatorios generados son: $U = {0.1573, 0.9454, 0.8211, 0.6996, 0.0318, 0.1708, 0.6865, 0.9102, 0.2579, 0.6344}$?

# %%
import random

def ale():
    return random.random()


lista=[[1,2,3,4,5,6,7,8],[0.11, 0.3,0.12,0.2,0.05,0.07,0.05,0.1]];
i=0;
lista2=[];

aux=0;
while i < 8:
    aux=aux+lista[1][i];
    
    lista2.append(aux);
    #print (aux);
    i=i+1;
i=1;
x=0;
u=[0.1573,0.9454,0.8211,0.6996,0.0318,0.1708,0.6865,0.9102,0.2579,0.6344]
if(u[0]<lista2[0]):
    x=lista2[0];
    
while i < 8:
    
    if(u[i]>=x and u[i]<lista2[i]):
        x=lista[0][i];
    
    
    
    i+=1;

#print("U = ",u);
print("valor X= ",x);
# Out:
# valor X=  4

# %% [markdown]
# **4)** Responda las siguientes preguntas:
#
# **(a)** Nombre dos distribuciones de probabilidad discreta.

# %%
Distribucion poison
Distribucion binomial

# %% [markdown]
# **(b)** ¿Cuáles son los parámetros de la distribución de probabilidad normal?

# %%
El valor de su media u
Desviacion estandar o-

# %% [markdown]
# **(c)** ¿Cuál es el valor esperado de una distribución de probabilidad uniforme continua que esta definida en el intervalo de 2 a 12?

# %% [markdown]
# **5)** Utilizando el metodo de Monte Carlo, y tomando como base el ejemplo del calculo del área del circulo visto en clase y del taller 3 con sus propios generadores congruenciales:
#
# **(a)** Implemente el metodo de Monte Carlo para calcular y mostrar el área estimada de una elipse con un semieje mayor $a = 13$ y semieje menor $b = 6$ centrado en el origen $x, y = (0, 0)$ generando 1000 coordenadas aleatorias $(X, Y)$ en el rango de
# $X = [−a, a]$ y $Y = [−b, b]$.<br>
# **(b)** Calcule el area real de la elipse.<br>
# **(c)** Calcule la diferencia entre el área real y el área estimada de la elipse con el método de Monte Carlo<br>
# **(d)** Grafique los puntos aleatorios generados que caen dentro de la elipse en rojo y los que caen fuera de la elipse en azul.

# %%
import numpy as np
import scipy as sp
from sympy import *
import math
from random import random
a=13
b=6
N = 1000
dentro = 0
fuera = 0
X=[]
Y=[]
Xr=[]
Yr=[]
Xb=[]
Yb=[]
for i in range(1, N+1):
    Ux = np.random.rand()
    Uy = np.random.rand()
    X.append(2*a*Ux-a)
    Y.append(2*b*Uy-b)
    I = (X[i-1]**2)/(a**2) + (Y[i-1]**2)/(b**2)
    if I <= 1:
        dentro  =dentro+1
        Xr.append(X[i-1])
        Yr.append(Y[i-1])
    else:
        fuera = fuera +1
        Xb.append(X[i-1])
        Yb.append(Y[i-1])

Aestimada = (float(dentro)/ float(N))*((4*b*a))
print("a) Area estimada = ", Aestimada)
Areal = np.pi*a*b

print("b) Area real de la elipse = ",Areal)


import matplotlib.pyplot as plt

x = np.arange(-float(a),float(a),float(a)/100.0)
#x.append(1)
y1=[]
y2=[]
for i in x:
    n = np.sqrt((1-((i**2)/a**2))*b**2)
    y1.append(n)
    y2.append(-n)
    


plt.plot(Xr, Yr, color="red",linewidth=0, marker='o', lw=1 )
plt.plot(Xb, Yb, color="blue",linewidth=0, marker='o', lw=1 )
titulo = " Diferencia = "+str(np.abs(Areal-Aestimada))
print("\nc) La diferencia entre el área real y el área estimada es=",(np.abs(Areal-Aestimada)),"\n")

print("\nd)")
plt.title(titulo)
plt.show()
# Out:
# a) Area estimada =  242.73600000000002
# b) Area real de la elipse =  245.04422698000388
#
# c) La diferencia entre el área real y el área estimada es= 2.308226980003866
#
#
# d)
